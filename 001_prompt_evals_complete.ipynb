# %%
print("hello")
# Out:
# hello

# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic
import os
load_dotenv()
load_dotenv(override=True)
client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.333333333333334

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\ndef extract_s3_bucket_name(s3_uri):\n    match = re.match(r's3://([a-zA-Z0-9._-]+)', s3_uri)\n    return match.group(1) if match else None\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from a given S3 URI (e.g., 's3://my-bucket-name/path/to/object') and extract only the bucket name",
#       "format": "regex",
#       "solution_criteria": "The regex should correctly extract bucket names from valid S3 URIs, handle bucket names with hyphens and numbers, and not match invalid URIs"
#     },
#     "score": 8.0,
#     "reasoning": "The solution successfully extracts bucket names from well-formed S3 URIs and handles the basic requirements. However, it does not enforce AWS S3 bucket naming rules comprehensively. The regex pattern `[a-zA-Z0-9._-]+` is too permissive\u2014it allows periods and hyphens in invalid positions. A production solution should either validate against strict AWS rules or at minimum reject bucket names with leading/trailing periods and hyphens. The error handling is appropriate, but overall robustness is limited."
#   },
#   {
#     "output": "\n{\n  \"FunctionName\": \"my-lambda-function\",\n  \"Runtime\": \"python3.11\",\n  \"Timeout\": 60,\n  \"MemorySize\": 256,\n  \"Environment\": {\n    \"Variables\": {\n      \"AWS_REGION\": \"us-east-1\"\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that specifies the function name, runtime (Python 3.11), timeout (60 seconds), memory (256 MB), and environment variables including AWS_REGION set to 'us-east-1'",
#       "format": "json",
#       "solution_criteria": "The JSON should be valid, include all required fields with correct data types, and follow AWS Lambda configuration naming conventions"
#     },
#     "score": 9.0,
#     "reasoning": "The solution correctly addresses all explicit requirements in the task: valid JSON, all specified fields included with proper naming conventions and data types. However, it lacks context about whether this is a complete deployable configuration or just a partial specification. The absence of a Role ARN and Handler field, while not explicitly required by the task, represents incompleteness for real-world AWS Lambda deployment, though the task may have intentionally scoped these out."
#   },
#   {
#     "output": "\nimport json\nimport re\nfrom typing import Any\n\n\ndef extract_actions(policy: dict) -> list[str]:\n    \"\"\"Extract all AWS service actions from an IAM policy document.\"\"\"\n    actions = []\n    \n    def process_value(value: Any) -> None:\n        if isinstance(value, str):\n            # Match action patterns like service:Action\n            if ':' in value and '*' not in value.split(':')[0]:\n                # Simple heuristic: if it contains : and looks like service:action\n                parts = value.split(':')\n                if len(parts) == 2 and parts[0].isalpha() and (parts[1].isalnum() or '*' in parts[1]):\n                    actions.append(value)\n            # Handle wildcards like s3:* or *\n            elif value == '*' or (isinstance(value, str) and ':*' in value):\n                actions.append(value)\n        elif isinstance(value, list):\n            for item in value:\n                process_value(item)\n        elif isinstance(value, dict):\n            for v in value.values():\n                process_value(v)\n    \n    # Process Statement array\n    if 'Statement' in policy:\n        statements = policy['Statement']\n        if isinstance(statements, list):\n            for statement in statements:\n                if isinstance(statement, dict):\n                    # Check Action field (can be string or list)\n                    if 'Action' in statement:\n                        process_value(statement['Action'])\n                    # Check Actions field (some policies use this)\n                    if 'Actions' in statement:\n                        process_value(statement['Actions'])\n    \n    return list(dict.fromkeys(actions))  # Remove duplicates while preserving order\n\n\n# Test with sample policy\nif __name__ == \"__main__\":\n    sample_policy = {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": [\n                    \"s3:GetObject\",\n                    \"s3:PutObject\",\n                    \"s3:*\"\n                ],\n                \"Resource\": \"arn:aws:s3:::my-bucket/*\"\n            },\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"dynamodb:Query\",\n                \"Resource\": \"arn:aws:dynamodb:us-east-1:123456789012:table/MyTable\"\n            },\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"*\",\n                \"Resource\": \"*\"\n            }\n        ]\n    }\n    \n    result = extract_actions(sample_policy)\n    print(json.dumps(result, indent=2))\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS IAM policy document (as a dictionary) and returns a list of all AWS service actions (e.g., 's3:GetObject', 'dynamodb:Query') granted in that policy",
#       "format": "python",
#       "solution_criteria": "The function should correctly extract Action values from Statement blocks, handle both string and list Action formats, and return a deduplicated list of actions"
#     },
#     "score": 8.0,
#     "reasoning": "The solution demonstrates a solid understanding of the core requirements and handles the primary use cases well. The recursive approach and wildcard handling are appropriate. However, the validation logic is problematic\u2014it filters out valid AWS service actions that contain numbers or hyphens, which are common in real AWS services and actions. The 'Actions' field reference is misleading since it doesn't exist in AWS IAM policy syntax. For production use, the function would fail on real-world policies containing services like 'apigatewayv2', 'kinesis-analytics', etc."
#   }
# ]
